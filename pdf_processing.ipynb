# %%
install pdfplumber
install tesseract and pytessearct
install PyMuPDF

# %% [markdown]
# ### Text from PDF

# %%
import fitz  # PyMuPDF

def extract_text_blocks(pdf_path):
    doc = fitz.open(pdf_path)
    items = []
    for page_num in range(len(doc)):
        page = doc[page_num]
        blocks = page.get_text("blocks")  # (x0, y0, x1, y1, text, block_no, type, ...)
        for b in blocks:
            x0, y0, x1, y1, text, *_ = b
            if text.strip():
                items.append({
                    "modality": "text",
                    "page": page_num + 1,
                    "bbox": (x0, y0, x1, y1),
                    "content": text.strip()
                })
    doc.close()
    return items
items = extract_text_blocks("./docs/doc.pdf")

# %%
items
# Out:
# [{'modality': 'text',
#   'page': 1,
#   'bbox': (72.02400207519531,
#    112.42996215820312,
#    429.59295654296875,
#    349.3399658203125),
#   'content': 'TCS AI Fridays – Participant Handbook'},
#  {'modality': 'text',
#   'page': 1,
#   'bbox': (72.02400207519531,
#    357.55999755859375,
#    508.35302734375,
#    386.2099914550781),
#   'content': 'VERSION 1.0'},
#  {'modality': 'text',
#   'page': 2,
#   'bbox': (442.8999938964844,
#    780.0660400390625,
#    530.8119506835938,
#    804.5999755859375),
#   'content': 'TCS Confidential | 2'},
#  {'modality': 'text',
#   'page': 2,
#   'bbox': (72.02400207519531,
#    76.54995727539062,
#    312.33294677734375,
#    113.29998779296875),
#   'content': 'Document Release Notice'},
#  {'modality': 'text',
#   'page': 2,
#   'bbox': (72.02400207519531,
#    128.17999267578125,
#    526.1199951171875,
#    156.97998046875),
#   'content': 'This TCS AI Fridays Hackathon – Participant Handbook, Version 1.0 is released for use in TATA \nConsultancy Services (TCS) with effect from 01/08/2025.'},
#  {'modality': 'text',
#   'page': 2,
#   'bbox': (72.02400207519531,
#    198.6199951171875,
#    389.9020080566406,
#    210.6199951171875),
#   'content': 'This document is subjected to TCS Document Control Procedure.'},
#  {'modality': 'text',
#   'page': 2,
#   'bbox': (72.02400207519531, 225.5, 361.1020202636719, 237.5),
#   'content': 'This document was last reviewed/updated on 01/08/2025.'},
#  {'modality': 'text',
#   'page': 2,
#   'bbox': (72.02400207519531,
#    279.16998291015625,
#    167.1320037841797,
#    291.16998291015625),
#   'content': 'Proposed By:  DCH'},
#  {'modality': 'text',
#   'page': 2,
#   'bbox': (72.02400207519531,
#    306.04998779296875,
#    254.28201293945312,
#    318.04998779296875),
#   'content': 'Approved By: Sridhar Venkataraman'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (442.8999938964844,
#    780.0660400390625,
#    530.8119506835938,
#    804.5999755859375),
#   'content': 'TCS Confidential | 3'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (72.02400207519531,
#    76.54995727539062,
#    190.1729736328125,
#    98.50995635986328),
#   'content': 'Revision List'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (77.66400146484375,
#    118.94000244140625,
#    123.08399963378906,
#    160.219970703125),
#   'content': 'Revision/\nVersion \nNo.'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (140.4199981689453,
#    118.94000244140625,
#    226.16001892089844,
#    160.219970703125),
#   'content': 'Document \nRelease/Revision \nDate'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (234.88999938964844,
#    118.94000244140625,
#    293.4020080566406,
#    145.5799560546875),
#   'content': 'Revision \nDescription'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (329.4700012207031,
#    118.94000244140625,
#    368.1819763183594,
#    145.5799560546875),
#   'content': 'Section \nNo.'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (387.9100036621094,
#    118.94000244140625,
#    447.2259826660156,
#    145.5799560546875),
#   'content': 'Rational for \nChange'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (77.66400146484375,
#    118.94000244140625,
#    519.052001953125,
#    190.0999755859375),
#   'content': 'Change type \n(add/modify\n/delete) \n1.0 \n01-08-2025 \nFirst release of \nthe document'},
#  {'modality': 'text',
#   'page': 3,
#   'bbox': (329.4700012207031,
#    163.4599609375,
#    472.8520202636719,
#    175.4599609375),
#   'content': 'NA \nNA \nNA'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (442.8999938964844,
#    780.0660400390625,
#    530.8119506835938,
#    804.5999755859375),
#   'content': 'TCS Confidential | 4'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    101.29998779296875,
#    160.77200317382812,
#    113.29998779296875),
#   'content': 'Table of Contents'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    125.6719970703125,
#    525.6519775390625,
#    141.6199951171875),
#   'content': '1. \nIntroduction ...................................................................................................................... 6'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    149.31201171875,
#    525.6519775390625,
#    165.260009765625),
#   'content': '2. \nPurpose ............................................................................................................................. 6'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    172.83197021484375,
#    525.6519775390625,
#    188.77996826171875),
#   'content': '3. \nScope ................................................................................................................................. 6'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    196.47198486328125,
#    525.6519775390625,
#    212.41998291015625),
#   'content': '4. \nOverview ........................................................................................................................... 6'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    219.99200439453125,
#    525.6519775390625,
#    235.94000244140625),
#   'content': '5. \nEligibility and Registration .............................................................................................. 7'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    243.511962890625,
#    525.6519775390625,
#    259.4599609375),
#   'content': '5.1. \nWho Can Participate ................................................................................................ 7'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    267.1820068359375,
#    525.6519775390625,
#    283.1300048828125),
#   'content': '5.2. \nRegistration Process ................................................................................................ 7'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    290.70196533203125,
#    525.6519775390625,
#    306.64996337890625),
#   'content': '6. \nTeam Formation ............................................................................................................... 7'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    314.22198486328125,
#    525.6519775390625,
#    330.16998291015625),
#   'content': '7. \nPre-Event Activities .......................................................................................................... 8'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    337.86199951171875,
#    525.6519775390625,
#    353.80999755859375),
#   'content': '7.1. \nOrientation ............................................................................................................... 8'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    361.3819885253906,
#    525.6519775390625,
#    377.3299865722656),
#   'content': '7.2. \nAccess Provisioning ................................................................................................. 8'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    385.02197265625,
#    525.6519775390625,
#    400.969970703125),
#   'content': '7.3. \nAI Lab Onboarding .................................................................................................. 8'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    408.5419921875,
#    525.6519775390625,
#    424.489990234375),
#   'content': '7.4. \nTool & Team Familiarization .................................................................................. 8'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    432.08197021484375,
#    525.6519775390625,
#    448.02996826171875),
#   'content': '8. \nDuring the Event .............................................................................................................. 8'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    455.72198486328125,
#    525.6519775390625,
#    471.66998291015625),
#   'content': '8.1. \nAgenda for Match Day ............................................................................................ 9'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    479.2419738769531,
#    525.6519775390625,
#    495.1899719238281),
#   'content': '8.2. \nCode of Conduct ...................................................................................................... 9'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    502.8819580078125,
#    525.6519775390625,
#    518.8299560546875),
#   'content': '8.3. \nData Usage & Ethics ................................................................................................ 9'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    526.4019775390625,
#    525.6519775390625,
#    542.3499755859375),
#   'content': '8.4. \nInteractions ............................................................................................................... 9'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    549.9219970703125,
#    525.6519775390625,
#    565.8699951171875),
#   'content': '8.5. \nDevelopment Guidelines ........................................................................................ 9'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    573.56201171875,
#    525.6519775390625,
#    589.510009765625),
#   'content': '8.6. \nDemo ......................................................................................................................... 9'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (96.02400207519531,
#    597.0819702148438,
#    525.6519775390625,
#    613.0299682617188),
#   'content': '8.6.1. \nSuggested Flow for Demo ............................................................................ 10'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (96.02400207519531,
#    620.6319580078125,
#    525.6519775390625,
#    636.5799560546875),
#   'content': '8.6.2. \nTime Management Tips ................................................................................ 10'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    644.27197265625,
#    525.6519775390625,
#    660.219970703125),
#   'content': '8.7. \nSubmission Guidelines .......................................................................................... 10'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    667.7919921875,
#    525.6519775390625,
#    683.739990234375),
#   'content': '8.8. \nEvaluation Criteria .................................................................................................. 10'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    691.4320068359375,
#    525.6519775390625,
#    707.3800048828125),
#   'content': '9. \nEscalation & Support .................................................................................................... 11'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (72.02400207519531,
#    714.9519653320312,
#    525.6519775390625,
#    730.8999633789062),
#   'content': '10. \nPost-Event Activities .................................................................................................. 11'},
#  {'modality': 'text',
#   'page': 4,
#   'bbox': (84.02400207519531,
#    738.468017578125,
#    525.6519775390625,
#    754.416015625),
#   'content': '10.1. \nAwards & Recognition ...................................................................................... 11'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (442.8999938964844,
#    780.0660400390625,
#    530.8119506835938,
#    804.5999755859375),
#   'content': 'TCS Confidential | 5'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (72.02400207519531,
#    72.031982421875,
#    525.6519775390625,
#    87.97998046875),
#   'content': '11. \nBenefits for Participant.............................................................................................. 11'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531, 95.552001953125, 525.6519775390625, 111.5),
#   'content': '11.1. \nLeadership Recognition .................................................................................... 11'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    119.19195556640625,
#    525.6519775390625,
#    135.13995361328125),
#   'content': '11.2. \nNetworking ......................................................................................................... 11'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    142.71197509765625,
#    525.6519775390625,
#    158.65997314453125),
#   'content': '11.3. \nSkill Sharpening ................................................................................................. 11'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    166.35198974609375,
#    525.6519775390625,
#    182.29998779296875),
#   'content': '11.4. \nContribution to Learning Culture .................................................................... 11'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    189.87200927734375,
#    525.6519775390625,
#    205.82000732421875),
#   'content': '11.5. \nRecognition ........................................................................................................ 11'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (72.02400207519531,
#    213.3919677734375,
#    525.6519775390625,
#    229.3399658203125),
#   'content': '12. \nKey Milestones & Timeline ....................................................................................... 12'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    237.031982421875,
#    525.6519775390625,
#    252.97998046875),
#   'content': '12.1. \nRound 1 Fridays: ................................................................................................ 12'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    260.58197021484375,
#    525.6519775390625,
#    276.52996826171875),
#   'content': '12.2. \nRound 2 Last Friday of the Quarter: ................................................................ 12'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    284.10198974609375,
#    525.6519775390625,
#    300.04998779296875),
#   'content': '12.3. \nQuarterly National Final – Residential: ........................................................... 12'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (72.02400207519531,
#    307.74200439453125,
#    525.6519775390625,
#    323.69000244140625),
#   'content': '13. \nAnnexure ................................................................................................................... 122'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    331.2619934082031,
#    525.6519775390625,
#    347.2099914550781),
#   'content': '13.1. \nGen AI Lab Setup ............................................................................................. 122'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    354.9019775390625,
#    525.6519775390625,
#    370.8499755859375),
#   'content': '13.2. \nPreinstalled Software List ................................................................................. 13'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    378.4219970703125,
#    525.6519775390625,
#    394.3699951171875),
#   'content': '13.3. \nPreinstalled Local SLMs List .............................................................................. 13'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    401.9419860839844,
#    525.6519775390625,
#    417.8899841308594),
#   'content': '13.4. \nPython Setup ...................................................................................................... 13'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    425.58197021484375,
#    525.6519775390625,
#    441.52996826171875),
#   'content': '13.5. \nList of currently available Models .................................................................... 14'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    449.1219787597656,
#    525.6519775390625,
#    465.0699768066406),
#   'content': '13.6. \nSample Code- To Test the environment ........................................................ 14'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    472.7619934082031,
#    525.6519775390625,
#    488.7099914550781),
#   'content': '13.7. \nSample Code- RAG Application ....................................................................... 15'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    496.281982421875,
#    525.6519775390625,
#    512.22998046875),
#   'content': '13.8. \nRegional SPOC Details ...................................................................................... 17'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531, 519.802001953125, 525.6519775390625, 535.75),
#   'content': '13.9. \nCompetency Details for Upskilling .................................................................. 19'},
#  {'modality': 'text',
#   'page': 5,
#   'bbox': (84.02400207519531,
#    543.4420166015625,
#    525.6519775390625,
#    559.3900146484375),
#   'content': '13.10. \nFrequently Asked Questions (FAQs) ............................................................... 19'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (442.8999938964844,
#    780.0660400390625,
#    530.8119506835938,
#    804.5999755859375),
#   'content': 'TCS Confidential | 6'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (81.02400207519531,
#    73.05500030517578,
#    212.99600219726562,
#    97.30999755859375),
#   'content': '1. Introduction'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (108.0199966430664,
#    103.94000244140625,
#    526.1319580078125,
#    267.52996826171875),
#   'content': "AI is redefining how we operate and use technology to create business value. The \npotential of AI is all encompassing: AI will solve business problems and create new \nopportunities, transforming how we deliver services to our customers. These are \nexciting times and each one of us should contribute with our ideas and expertise to \nrealize the potential of AI. tcsAI (to be read as 'TCS to the power of AI') is bringing AI \ncloser to you through AI/GenAI hackathons and in-person labs (AI Fridays) at branch \nlevel. It is an intensive, innovation-driven event where participants come together to \nsolve real-world problems using artificial intelligence and machine learning. Over a \nlimited time frame, teams will design, build, and present AI-powered solutions across \nvarious domains such as manufacturing, healthcare, finance, sustainability, and more."},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (81.02400207519531,
#    283.0849609375,
#    172.67095947265625,
#    307.3399658203125),
#   'content': '2. Purpose'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (108.0199966430664,
#    313.8499755859375,
#    526.1319580078125,
#    359.5699768066406),
#   'content': 'This handbook will guide you through everything you need to know to make the most \nof your hackathon experience. It also outlines the roles, responsibilities, protocols, \nmodels, FAQs for participants. Provide resources and references to ensure success.'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (81.02400207519531,
#    375.1249694824219,
#    153.57200622558594,
#    399.3799743652344),
#   'content': '3. Scope'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (108.0199966430664,
#    405.8899841308594,
#    460.61199951171875,
#    417.8899841308594),
#   'content': 'This handbook applies to all participants involved in the AI Friday event.'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (81.02400207519531,
#    433.4649658203125,
#    185.2519989013672,
#    457.719970703125),
#   'content': '4. Overview'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (108.0199966430664,
#    464.22998046875,
#    526.1319580078125,
#    560.469970703125),
#   'content': 'Here is the overview of the complete process at high level. The participant journey in \nthe AI Friday is designed to provide structured engagement, enabling participants to \neffectively collaborate, experiment on real world use case and enriching their own \nlearning experience. If you encounter any issues, please contact your branch SPOC \nlisted in the Annexure. Refer: 13.8'},
#  {'modality': 'text',
#   'page': 6,
#   'bbox': (72.02400207519531,
#    757.14599609375,
#    194.9239959716797,
#    766.14599609375),
#   'content': 'Figure 1 Participant Journey Map'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (442.8999938964844,
#    780.0660400390625,
#    530.8119506835938,
#    804.5999755859375),
#   'content': 'TCS Confidential | 7'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (81.02400207519531,
#    73.05500030517578,
#    329.7820129394531,
#    97.30999755859375),
#   'content': '5. Eligibility and Registration'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (108.0199966430664,
#    103.94000244140625,
#    449.0920104980469,
#    115.94000244140625),
#   'content': 'This section outlines eligibility requirements and registration process.'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (90.02400207519531,
#    129.03378295898438,
#    266.3830261230469,
#    145.24998474121094),
#   'content': '5.1. \nWho Can Participate'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (126.0199966430664,
#    148.03997802734375,
#    526.0538940429688,
#    180.6199951171875),
#   'content': '• AI Fridays is currently planned for TCS India associates only \n• Open to all TCS Full time associates who have a passion for AI/ML, data science,'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (126.0199966430664,
#    185.41998291015625,
#    526.0960083007812,
#    214.94000244140625),
#   'content': 'or problem-solving \n• Pre-requisite - Basic knowledge of Python and LLM is needed. If you lack'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (126.0199966430664,
#    219.739990234375,
#    526.1199340820312,
#    266.0899658203125),
#   'content': 'knowledge in these areas and wish to upskill, please refer to the courses listed \nin the section. Refer: 13.9 \n• Participants can join as individuals or form a team of 5 members, out of which'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (144.02000427246094,
#    270.88995361328125,
#    416.1820068359375,
#    282.88995361328125),
#   'content': 'minimum 2 associates should be of Grades C1 or below'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (90.02400207519531,
#    296.1037902832031,
#    265.06304931640625,
#    312.32000732421875),
#   'content': '5.2. \nRegistration Process'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (126.0199966430664,
#    315.1099853515625,
#    526.1199951171875,
#    365.0899963378906),
#   'content': '• Complete the online registration form at this link - Nomination Form \n• Specify whether you are nominating a team or registering as an individual. \n• If you are nominating as a team, please include your team’s name, team'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (126.0199966430664,
#    369.8899841308594,
#    526.1319580078125,
#    449.9499816894531),
#   'content': 'members’ Employee IDs, your years of experience, preferred date for \nparticipation (one of the Friday’s listed), BG Name, TCS Office location, skill set, \nmobile number with consent, T-shirt size. Please be aware of this date is a \npreference and your Branch SPOC will confirm the same. \n• For team nominations, ensure that each team member fills out the form'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (144.02000427246094,
#    454.7499694824219,
#    526.1319580078125,
#    483.54998779296875),
#   'content': 'separately and refer the same team’s name and team member employee id’s. \nMismatch in this will lead to not having the preferred team members.'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (81.02400207519531,
#    499.10498046875,
#    247.79600524902344,
#    523.3599853515625),
#   'content': '6. Team Formation'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (108.0199966430664,
#    529.8699951171875,
#    525.8899536132812,
#    558.7899780273438),
#   'content': 'Teams should be diverse in skills and experience, promoting learning and \ncollaboration. Balanced teams often lead to better, well-rounded solutions'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (108.0199966430664,
#    573.5499877929688,
#    165.33200073242188,
#    585.5499877929688),
#   'content': 'Guidelines:'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (126.0199966430664,
#    598.0899658203125,
#    525.9259033203125,
#    613.1499633789062),
#   'content': '• Team size: 5 members out of which minimum 2 associates should be of Grades'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (144.02000427246094,
#    623.1400146484375,
#    205.08200073242188,
#    635.1400146484375),
#   'content': 'C1 or below'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (126.0199966430664,
#    642.7599487304688,
#    526.1199951171875,
#    657.8199462890625),
#   'content': '• Teams can be self-formed before the event, and all members should mention'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (144.02000427246094,
#    667.6599731445312,
#    478.73199462890625,
#    679.6599731445312),
#   'content': 'the same team’s name while registering as mentioned in section 5.2'},
#  {'modality': 'text',
#   'page': 7,
#   'bbox': (126.0199966430664,
#    687.2799682617188,
#    478.9720153808594,
#    702.3399658203125),
#   'content': '• For individual nominations, teams will be randomly formed using AI'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (442.8999938964844,
#    780.0660400390625,
#    530.8119506835938,
#    804.5999755859375),
#   'content': 'TCS Confidential | 8'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (81.02400207519531,
#    73.05500030517578,
#    273.83599853515625,
#    97.30999755859375),
#   'content': '7. Pre-Event Activities'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (90.02400207519531,
#    104.19376373291016,
#    526.0059204101562,
#    171.260009765625),
#   'content': '7.1. \nOrientation  \nA structured orientation ensures participants understand the hackathon process, \nexpectations, and available resources. This will be conducted during the match week. \nParticipants will be notified through the branch SPOCs.'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664,
#    176.05999755859375,
#    393.0220031738281,
#    240.6199951171875),
#   'content': 'Orientation Includes: \n• Overview of event structure and timelines \n• Meet and greet with mentors and organizing team \n• Q&A session to address any participant queries'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664,
#    255.40997314453125,
#    501.8919982910156,
#    267.40997314453125),
#   'content': 'Attendance is highly recommended to align with expectations and timelines.'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (90.02400207519531, 285.7837829589844, 260.5030212402344, 302.0),
#   'content': '7.2. \nAccess Provisioning'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664,
#    304.66998291015625,
#    526.119873046875,
#    319.72998046875),
#   'content': '• Access will be granted every Monday only to the nominated participants for'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664,
#    324.52996826171875,
#    525.1719970703125,
#    371.5699768066406),
#   'content': 'the match week \n• Ensure you have access to the designated location  \n• If you do not have access to the building, raise a 2Office request via Ultimatix'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (90.02400207519531,
#    384.6637878417969,
#    255.10302734375,
#    400.8800048828125),
#   'content': '7.3. \nAI Lab Onboarding'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664,
#    403.66998291015625,
#    526.1199340820312,
#    418.72998046875),
#   'content': '• Once access and login credentials are received, visit the AI Lab at your'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664,
#    423.52996826171875,
#    301.56201171875,
#    453.0699768066406),
#   'content': 'respective Location. Refer: 13.8 \n• Verify your login credentials'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (90.02400207519531,
#    466.1637878417969,
#    310.54302978515625,
#    482.3800048828125),
#   'content': '7.4. \nTool & Team Familiarization'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664,
#    485.16998291015625,
#    525.7039794921875,
#    500.22998046875),
#   'content': '• Explore and get comfortable with the AI tools that will be used during the'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664,
#    504.90997314453125,
#    525.805908203125,
#    552.0699462890625),
#   'content': 'Hackathon \n• You can use AI lab as playground to learn from Monday to Thursday \n• Also use this as an opportunity to understand/appreciate your fellow team'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (126.0199966430664, 556.75, 496.0119934082031, 586.3900146484375),
#   'content': 'members (those teams formed by AI). \n• Refer the Annexure section for sample code and list of available models'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (81.02400207519531,
#    601.85498046875,
#    247.58096313476562,
#    626.1099853515625),
#   'content': '8. During the Event'},
#  {'modality': 'text',
#   'page': 8,
#   'bbox': (108.0199966430664,
#    632.6199951171875,
#    526.1199951171875,
#    762.5759887695312),
#   'content': 'During the event, participant will work closely with mentors for guidance and, support. \nMentors will be randomly assigned to each team. This section explains the \nexpectations for interactions, collaboration, and conduct during the event. The event \ntimings provided are indicative. Please connect with your Branch SPOC for specific \nevent timings & details, as they can vary for each branch.'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (442.8999938964844,
#    780.0660400390625,
#    530.8119506835938,
#    804.5999755859375),
#   'content': 'TCS Confidential | 9'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (90.02400207519531,
#    72.7537612915039,
#    277.54302978515625,
#    88.96996307373047),
#   'content': '8.1. \nAgenda for Match Day'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (124.45999908447266,
#    94.5799560546875,
#    505.37200927734375,
#    106.5799560546875),
#   'content': '# \nTopic \nStart Time \nEnd Time \nDuration'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (122.66000366210938,
#    116.41998291015625,
#    485.3320007324219,
#    128.41998291015625),
#   'content': '1 \nMatch Time \n2:00 PM \n7.00 PM \n5:00'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (122.66000366210938,
#    139.3399658203125,
#    482.6920166015625,
#    151.3399658203125),
#   'content': '2 \nDemo & Evaluation \n7:00 PM \n8:00 PM \n1:00'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (122.66000366210938,
#    161.17999267578125,
#    482.6920166015625,
#    173.17999267578125),
#   'content': '3 \nAnnounce winners \n8:00 PM \n8:30 PM \n0:30'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (90.02400207519531,
#    183.27377319335938,
#    243.22303771972656,
#    199.48997497558594),
#   'content': '8.2. \nCode of Conduct'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (126.0199966430664,
#    202.39996337890625,
#    493.8520202636719,
#    304.8499755859375),
#   'content': '• Maintain ethical behaviour and inclusive communication \n• Respect others’ ideas, time, and effort \n• Avoid the use of proprietary data or unauthorized tools \n• Inform organizers well in advance in case of changes in your availability \n• Adhere to the Tata code of conduct in its entirety   \n• During conflicts organizers decision shall be conclusive'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (90.02400207519531,
#    317.94378662109375,
#    263.5030212402344,
#    334.1600036621094),
#   'content': '8.3. \nData Usage & Ethics'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (126.0199966430664,
#    336.9499816894531,
#    526.1319580078125,
#    352.0099792480469),
#   'content': '• Use only open-source or provided datasets or you can create your own'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (126.0199966430664,
#    356.80999755859375,
#    525.763916015625,
#    386.3299865722656),
#   'content': 'synthetic data \n• Ensure responsible AI principles are followed: fairness, accountability, and'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (126.0199966430664,
#    391.1299743652344,
#    367.3420104980469,
#    420.6499938964844),
#   'content': 'transparency \n• Cite all datasets and pre-trained models used'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (90.02400207519531,
#    433.7637634277344,
#    217.0630340576172,
#    449.97998046875),
#   'content': '8.4. \nInteractions'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (126.0199966430664,
#    452.7699890136719,
#    526.1199951171875,
#    467.8299865722656),
#   'content': '• Prepare your queries or blockers in advance for effective discussion with'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (126.0199966430664,
#    472.6299743652344,
#    526.005859375,
#    502.1499938964844),
#   'content': 'mentors \n• Collaborate within team effectively to build the solution and ensure every'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (144.02000427246094, 506.949951171875, 526.0299072265625, 535.75),
#   'content': 'team member has a role to play. Evaluation criteria will consider this aspect \n(Refer section 8.8)'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (90.02400207519531,
#    548.9638061523438,
#    290.7430419921875,
#    565.1799926757812),
#   'content': '8.5. \nDevelopment Guidelines'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (126.0199966430664,
#    567.969970703125,
#    489.4120178222656,
#    653.02001953125),
#   'content': '• Use proper code commenting and modular design \n• Use a popular /scalable Framework to build the solution \n• Choose a Vector database or traditional database wherever applicable \n• Avoid using ChatGPT to craft the entire solution \n• Avoid cloning GitHub repositories for developing the entire solution'},
#  {'modality': 'text',
#   'page': 9,
#   'bbox': (90.02400207519531,
#    666.11376953125,
#    526.1199340820312,
#    749.9759521484375),
#   'content': '8.6. \nDemo \nDuring the final stage of the hackathon, each team will present their AI solution to \nthe jury and audience. This is your opportunity to showcase the problem-solving \napproach, technical implementation, and the impact of your project — concisely \nand convincingly.'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (437.739990234375,
#    780.0660400390625,
#    530.6919555664062,
#    804.5999755859375),
#   'content': 'TCS Confidential | 10'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    74.39996337890625,
#    525.9819946289062,
#    120.13995361328125),
#   'content': 'Each team will get exactly 5 minutes to present. Ensure that everyone has the \nopportunity to speak. Time management is critical — plan your demo to highlight \nthe essence of your work effectively.'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (108.0199966430664,
#    133.0399627685547,
#    274.0820007324219,
#    146.89996337890625),
#   'content': '8.6.1. Suggested Flow for Demo'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    149.47998046875,
#    526.0299682617188,
#    164.53997802734375),
#   'content': '• Introduction (30 sec): Briefly state your team’s name, problem statement, and'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    169.3399658203125,
#    525.9019165039062,
#    198.8599853515625),
#   'content': 'the objective of your solution.  \n• Problem Context (30 sec): What challenge are you solving and why is it'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    203.65997314453125,
#    525.9498291015625,
#    233.17999267578125),
#   'content': 'important? \n• Solution Overview (1 min): Describe the AI model, approach taken, tools used,'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    237.97998046875,
#    525.9219360351562,
#    267.52996826171875),
#   'content': 'and any innovation introduced. \n• Live Demo or Walkthrough (2 min): Demonstrate your working prototype or'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    272.3299560546875,
#    525.9378051757812,
#    301.8499755859375),
#   'content': 'solution flow with emphasis on usability and impact. \n• Results & Metrics (30 sec): Present performance metrics (e.g., accuracy,'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    306.64996337890625,
#    525.9020385742188,
#    336.16998291015625),
#   'content': 'precision, AUC), validations, or comparisons with baseline. \n• Conclusion (30 sec): Summarize key outcomes, limitations (if any), and'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (144.02000427246094,
#    340.969970703125,
#    297.7220153808594,
#    352.969970703125),
#   'content': 'possible future enhancements.'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (108.0199966430664,
#    365.989990234375,
#    263.88201904296875,
#    379.8499755859375),
#   'content': '8.6.2. Time Management Tips'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (133.22000122070312,
#    382.30999755859375,
#    526.1319580078125,
#    449.1099853515625),
#   'content': '• Assign a presenter for each flow, rehearse to stay within the time. \n• Avoid spending too much time on theoretical background. \n• Prioritize clarity and flow over technical depth — jury may ask follow-up \nquestions afterward.'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (90.02400207519531,
#    462.3237609863281,
#    526.0719604492188,
#    512.469970703125),
#   'content': '8.7. \nSubmission Guidelines \nEach team must submit their solution within the defined timeline, and it must \ninclude:'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    525.0099487304688,
#    525.993896484375,
#    574.989990234375),
#   'content': '• Source code with README \n• Model notebook(s) or pipeline with explanation \n• Presentation deck containing Problem statement, Solution approach, AI/ML'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    579.7899780273438,
#    335.7820129394531,
#    609.3099975585938),
#   'content': 'techniques and Challenges Faced \n• Demo video (max 5 minutes) -Optional'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (90.02400207519531,
#    622.433837890625,
#    476.5719909667969,
#    655.7799682617188),
#   'content': '8.8. \nEvaluation Criteria \nProjects are evaluated on a blend of innovation, impact, and execution.'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    670.6599731445312,
#    226.802001953125,
#    682.6599731445312),
#   'content': 'Scoring Parameters:'},
#  {'modality': 'text',
#   'page': 10,
#   'bbox': (126.0199966430664,
#    695.2000122070312,
#    371.302001953125,
#    762.6959838867188),
#   'content': '• Participation and engagement during sessions \n• Successful completion of hands-on activities \n• Completion of the working application \n• Creativity and innovation in the given projects'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (437.739990234375,
#    780.0660400390625,
#    530.6919555664062,
#    804.5999755859375),
#   'content': 'TCS Confidential | 11'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (126.0199966430664,
#    72.0799560546875,
#    492.6520080566406,
#    87.13995361328125),
#   'content': '• Participation and demonstration of understanding quizzes and debates'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (81.02400207519531,
#    102.57495880126953,
#    286.1960144042969,
#    126.8299560546875),
#   'content': '9. Escalation & Support'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (108.0199966430664,
#    133.3399658203125,
#    525.9700317382812,
#    162.260009765625),
#   'content': "Sometimes challenges arise that participant can't resolve alone. This section provides \nthe protocol for raising concerns or requesting help from organizers."},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (126.0199966430664,
#    164.719970703125,
#    510.4120178222656,
#    179.77996826171875),
#   'content': '• Escalate technical issues or rule violations to the branch SPOC. Refer: 13.8'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (81.02400207519531,
#    195.2149658203125,
#    291.83599853515625,
#    219.469970703125),
#   'content': '10. Post-Event Activities'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (108.0199966430664,
#    226.0999755859375,
#    526.0059204101562,
#    271.72998046875),
#   'content': 'After the event, participant may participate in feedback, Demo. This section outlines \npost-event responsibilities. \nSelected solutions may receive further attention, development support, or exposure.'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (90.02400207519531,
#    284.9437561035156,
#    478.49200439453125,
#    318.28997802734375),
#   'content': '10.1. \nAwards & Recognition \nTop-performing teams as evaluated by the Jury will be duly recognized.'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (81.02400207519531,
#    333.7249755859375,
#    314.8760070800781,
#    357.97998046875),
#   'content': '11. Benefits for Participant'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (108.0199966430664,
#    364.6099853515625,
#    526.095947265625,
#    410.3299865722656),
#   'content': "Participating in the AI Friday event is not just about gamified playground; it's also a \nrewarding and enriching learning experience. This section outlines the personal and \nprofessional benefits participants gain from participating."},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (90.02400207519531,
#    423.42376708984375,
#    283.06304931640625,
#    439.6399841308594),
#   'content': '11.1. \nLeadership Recognition'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (126.0199966430664,
#    442.4499816894531,
#    525.66796875,
#    457.5099792480469),
#   'content': '• Opportunity to be recognized as a domain expert and thought leader within'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (144.02000427246094,
#    462.30999755859375,
#    226.6820068359375,
#    474.30999755859375),
#   'content': 'the organization'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (90.02400207519531,
#    487.4037780761719,
#    215.62303161621094,
#    503.6199951171875),
#   'content': '11.2. \nNetworking'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (126.0199966430664,
#    506.40997314453125,
#    525.8298950195312,
#    521.469970703125),
#   'content': '• Connect with like-minded professionals, tech leaders, and emerging AI talent'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (144.02000427246094,
#    526.27001953125,
#    324.86199951171875,
#    538.27001953125),
#   'content': 'across departments or organizations'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (90.02400207519531,
#    551.4837646484375,
#    239.7430419921875,
#    567.699951171875),
#   'content': '11.3. \nSkill Sharpening'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (126.0199966430664,
#    570.3699951171875,
#    525.9337768554688,
#    585.4299926757812),
#   'content': '• Exposure to fresh ideas and problem-solving approaches can help sharpen'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (126.0199966430664, 590.22998046875, 525.8359375, 619.8699951171875),
#   'content': 'your own AI/ML skills and perspectives \n• Hands-on experience with AI tools and technologies with an open environment'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (144.02000427246094,
#    624.5799560546875,
#    199.20201110839844,
#    636.5799560546875),
#   'content': 'to explore'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (90.02400207519531,
#    649.7938232421875,
#    335.8830261230469,
#    666.010009765625),
#   'content': '11.4. \nContribution to Learning Culture'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (126.0199966430664,
#    668.7999877929688,
#    525.7279663085938,
#    683.8599853515625),
#   'content': '• Be a key part of promoting innovation, continuous learning, and ethical AI'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (144.02000427246094,
#    688.5399780273438,
#    285.36199951171875,
#    700.5399780273438),
#   'content': 'practices in your community'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (90.02400207519531,
#    713.7537841796875,
#    216.46302795410156,
#    729.969970703125),
#   'content': '11.5. \nRecognition'},
#  {'modality': 'text',
#   'page': 11,
#   'bbox': (126.0199966430664,
#    732.7559814453125,
#    523.7319946289062,
#    747.8159790039062),
#   'content': '• Teams that excel and are recognized by the Jury will receive due recognition.'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (437.739990234375,
#    780.0660400390625,
#    530.6919555664062,
#    804.5999755859375),
#   'content': 'TCS Confidential | 12'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (81.02400207519531,
#    73.05500030517578,
#    345.6159973144531,
#    97.30999755859375),
#   'content': '12. Key Milestones & Timeline'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (108.0199966430664,
#    103.94000244140625,
#    526.005859375,
#    132.739990234375),
#   'content': 'To help you plan and stay on track, here is a snapshot of the key phases and important \ndates for the TCS AI Fridays Hackathon:'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (90.02400207519531,
#    145.95376586914062,
#    243.9430389404297,
#    162.1699676513672),
#   'content': '12.1. \nRound 1 Fridays:'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (126.0199966430664,
#    164.9599609375,
#    526.1079711914062,
#    180.01995849609375),
#   'content': '• Every Week 10 to 20 New Teams will be identified. Each team will get 1 new'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (126.0199966430664,
#    184.70001220703125,
#    448.13201904296875,
#    249.260009765625),
#   'content': 'real world AI problem  \n• Monday to Thursday – Pre Match Coaching \n• Friday is the main competition \n• 1 Team qualifies for the next round of Quarterly Branch Finals'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (90.02400207519531,
#    262.3837585449219,
#    291.4630432128906,
#    278.5999755859375),
#   'content': '12.2. \nQuarterly Regional Final:'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (126.0199966430664,
#    281.3900146484375,
#    526.1320190429688,
#    296.45001220703125),
#   'content': '• Every Quarter, Weekly winning teams from Round 1 Qualifier compete at'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (126.0199966430664, 301.25, 526.1199951171875, 348.28997802734375),
#   'content': 'Quarterly Branch Finals to progress for Quarterly National Finals \n• More Advanced real-world problems will be given to solve \n• 2 Teams each from large branches (Bangalore, Chennai, Delhi, Hyderabad,'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (144.02000427246094,
#    352.969970703125,
#    526.1199951171875,
#    381.8899841308594),
#   'content': 'Kolkata, Mumbai & Pune) and 1 team each from other branches qualify to the \nQuarterly National Final'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (90.02400207519531,
#    394.9837646484375,
#    368.8830261230469,
#    411.1999816894531),
#   'content': '12.3. \nQuarterly National Final – Residential:'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (126.0199966430664,
#    413.989990234375,
#    494.81201171875,
#    481.5099792480469),
#   'content': '• Every Quarter, Regional Winning Teams of every branch will participate \n• Advanced Problem to Solve \n• 1 Quarterly National Winners \n• Quarterly Celebration'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (81.02400207519531,
#    496.9449462890625,
#    197.63600158691406,
#    521.199951171875),
#   'content': '13. Annexure'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (108.0199966430664,
#    527.8299560546875,
#    526.0059814453125,
#    556.6300048828125),
#   'content': 'Reference materials to understand infrastructure set up and alignment with event \ngoals.'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (72.02400207519531,
#    569.8438110351562,
#    526.1319580078125,
#    636.8199462890625),
#   'content': '13.1. \nGen AI Lab Setup \nLaptop pre-loaded with python, VS Code, AI tools, shared folder for team collaboration \nwill be available at AI Lab. These laptops are not in TCS network, you cannot access Teams, \nMailbox etc. They have access to open Internet to explore all open AI tools and technologies.'},
#  {'modality': 'text',
#   'page': 12,
#   'bbox': (126.0199966430664,
#    649.3599853515625,
#    437.5419921875,
#    664.4199829101562),
#   'content': '• Below is the high-level Architecture of the Gen AI Lab Setup'},
#  {'modality': 'text',
#   'page': 13,
#   'bbox': (437.739990234375,
#    780.0660400390625,
#    530.6919555664062,
#    804.5999755859375),
#   'content': 'TCS Confidential | 13'},
#  {'modality': 'text',
#   'page': 13,
#   'bbox': (72.02400207519531,
#    336.0199890136719,
#    214.60400390625,
#    345.0199890136719),
# ...
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (378.30999755859375,
#    215.89999389648438,
#    472.155029296875,
#    226.9399871826172),
#   'content': 'Hirakud - 2F-ADC-2B'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (113.41999816894531,
#    270.1700134277344,
#    242.30503845214844,
#    294.64996337890625),
#   'content': 'Indore \n1. 2312426 \n2. 355465'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (270.2900085449219,
#    270.1700134277344,
#    355.96502685546875,
#    294.64996337890625),
#   'content': '1. Kriyesh Patidar \n2. Shikhar Dadhich'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (378.30999755859375,
#    270.1700134277344,
#    482.1150207519531,
#    281.21002197265625),
#   'content': 'Ground Floor, L1 Block'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (113.41999816894531,
#    300.6499938964844,
#    236.6650390625,
#    352.0099792480469),
#   'content': 'Kochi \n1. 142447 \n2. 170419 \n3. 108149 \n4. 142418'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (270.2900085449219,
#    300.6499938964844,
#    357.7650146484375,
#    365.4499816894531),
#   'content': '1. Arun Narayan \nThekkethil \n2. Prasad Panthayil \n3. Reeja George \n4. Robin John'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (378.30999755859375,
#    300.6499938964844,
#    519.7772827148438,
#    325.1300048828125),
#   'content': '"Gurukool”, 6th Floor, Vismaya \nBuilding, Infopark'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (113.41999816894531,
#    368.3299865722656,
#    489.9150390625,
#    408.28997802734375),
#   'content': 'Trivandrum \n1. 158296 \n1. Rakesh Unnee \nBlock B, 2nd floor ODC 4 \nNagpur \n1. 333913 \n2. 869063'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (270.2900085449219,
#    383.80999755859375,
#    356.4450378417969,
#    408.28997802734375),
#   'content': '1. Devashish Rao \n2. Sarang Bhalerao'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (378.30999755859375,
#    383.80999755859375,
#    468.9150390625,
#    394.8500061035156),
#   'content': 'EB7, G Floor, ODC C'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (113.41999816894531,
#    414.28997802734375,
#    236.6650390625,
#    438.7699890136719),
#   'content': 'Lucknow \n1. 107613 \n2. 141183'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (270.2900085449219,
#    414.28997802734375,
#    348.2850341796875,
#    438.7699890136719),
#   'content': '1. Ambili K \n2. Manish Rajput'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (378.30999755859375,
#    414.28997802734375,
#    498.6750183105469,
#    425.3299865722656),
#   'content': '7th Floor, TCS Awadh Park'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (113.41999816894531,
#    441.66998291015625,
#    242.30503845214844,
#    466.1499938964844),
#   'content': 'Varanasi \n1. 143210 \n2. 1529363'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (270.2900085449219,
#    441.66998291015625,
#    342.64501953125,
#    466.1499938964844),
#   'content': '1. Ravi Kohli \n2. Dhruv Kumar'},
#  {'modality': 'text',
#   'page': 18,
#   'bbox': (378.30999755859375,
#    441.66998291015625,
#    528.4929809570312,
#    466.1499938964844),
#   'content': 'TCS Siddha Complex, Floor 2, 3 & \n4 Internet Kiosk Rooms'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (437.739990234375,
#    780.0660400390625,
#    530.6919555664062,
#    804.5999755859375),
#   'content': 'TCS Confidential | 19'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (90.02400207519531,
#    72.7537612915039,
#    526.1199951171875,
#    156.6199951171875),
#   'content': '13.9. \nCompetency Details for Upskilling  \nTo enhance your skills in AI development, please refresh your competencies listed \nbelow. Additionally, reach out to your branch TD for other upskilling programs on AI/Gen \nAI. A foundational understanding in any of these competencies, among others, will enable \nyou to participate effectively in AI Fridays.'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (113.54000091552734,
#    171.97998046875,
#    438.2619934082031,
#    319.3699951171875),
#   'content': 'S.No. \nCourse ID \nCourse Name \nLink \n1. \n5386 \nDigital: Python \niEvolve \n2. \n5406 \nDigital: Deep Learning \niEvolve \n3. \n5407 \nDigital: Machine Learning \niEvolve \n4. \n5416 \nDigital: Artificial Intelligence \niEvolve \n5. \n6618 \nGenerative AI \niEvolve \n6.  \n62757 \nLearning REST APIs \niEvolve \n7. \n83068 \nAgentic AI Fundamentals: \nArchitectures, Frameworks, \nand Applications_LinkedIn'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (399.9100036621094,
#    277.969970703125,
#    438.2619934082031,
#    289.969970703125),
#   'content': 'iEvolve'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (113.54000091552734,
#    322.489990234375,
#    391.7060241699219,
#    363.7699890136719),
#   'content': '8. \n83071 \nAgentic AI for Developers: \nConcepts and Application for \nEnterprises_LinkedIn'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (399.9100036621094,
#    322.489990234375,
#    438.2619934082031,
#    334.489990234375),
#   'content': 'iEvolve'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (90.02400207519531,
#    392.1037902832031,
#    352.56304931640625,
#    425.4499816894531),
#   'content': '13.10. \nFrequently Asked Questions (FAQs) \n13.10.1. What is the AI Lab?'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (108.0199966430664,
#    440.22998046875,
#    526.1080322265625,
#    502.8699951171875),
#   'content': 'The AI Lab is a collaborative learning and development environment focused on \nexploring, building, and experimenting with artificial intelligence technologies. The AI \nLab hosts essential tools like Jupyter Notebooks, VS Code, Python libraries (e.g., \nTensorFlow, PyTorch), and shared folder for real-time collaboration with team.'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (96.38400268554688,
#    515.77001953125,
#    304.2019958496094,
#    529.6300048828125),
#   'content': '13.10.2. Who Provides Access to AI Lab?'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (108.0199966430664,
#    544.510009765625,
#    526.10791015625,
#    573.3099975585938),
#   'content': 'Regional SPOC is responsible for managing and provisioning AI Lab access. Refer: \n13.8'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (96.38400268554688,
#    586.3300170898438,
#    346.8219909667969,
#    600.1900024414062),
#   'content': '13.10.3. What to Expect After Access is Granted?'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (133.22000122070312,
#    615.0999755859375,
#    424.9420166015625,
#    627.0999755859375),
#   'content': 'Login Details: Sent via email with secure link and password.'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (133.22000122070312,
#    641.97998046875,
#    468.4120178222656,
#    653.97998046875),
#   'content': 'Environment: Pre-configured Laptop with core AI tools and libraries.'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (96.38400268554688,
#    666.8800048828125,
#    333.62200927734375,
#    680.739990234375),
#   'content': '13.10.4. What is the purpose of the Program?'},
#  {'modality': 'text',
#   'page': 19,
#   'bbox': (108.0199966430664,
#    695.6199951171875,
#    526.0059814453125,
#    758.135986328125),
#   'content': 'The AI Friday aims to foster innovation and problem-solving through the \ndevelopment of AI-powered tools that align with real-world business challenges and \nemerging technology trends. It is an opportunity to showcase talent, creativity, and \ntechnical expertise.'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (437.739990234375,
#    780.0660400390625,
#    530.6919555664062,
#    804.5999755859375),
#   'content': 'TCS Confidential | 20'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    72.53996276855469,
#    253.20201110839844,
#    86.39996337890625),
#   'content': '13.10.5. Who can participate?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (108.0199966430664,
#    101.29998779296875,
#    526.0180053710938,
#    130.0999755859375),
#   'content': 'Anyone within TCS with passion to solve problem using AI - from beginners to \nexperienced professionals. Basic knowledge of Python and LLMs is essential.'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    143.11997985839844,
#    393.50201416015625,
#    156.97998046875),
#   'content': '13.10.6. Do I need prior experience in AI or programming?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (133.22000122070312,
#    171.8599853515625,
#    383.1820068359375,
#    183.8599853515625),
#   'content': 'Yes, participants should understand Python, GenAI'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    196.75999450683594,
#    411.86199951171875,
#    210.6199951171875),
#   'content': '13.10.7. What if I do not have experience in Python or GenAI?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (133.22000122070312, 225.5, 434.4219970703125, 237.5),
#   'content': 'You can connect with Talent Development to upskill yourself.'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    250.52000427246094,
#    432.98199462890625,
#    264.3800048828125),
#   'content': '13.10.8. What kind of projects or activities will we be working on?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (108.0199966430664,
#    279.16998291015625,
#    523.6119995117188,
#    308.0899658203125),
#   'content': 'Projects may range from building ML models and using AI APIs to tackling real-\nworld problems with data-driven solutions'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    320.989990234375,
#    348.2619934082031,
#    334.8499755859375),
#   'content': '13.10.9. Is this a team-based or individual event?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (108.0199966430664,
#    349.72998046875,
#    526.10791015625,
#    395.4499816894531),
#   'content': 'It’s a team event, either you can form your own team and nominate or nominate \nindividually (Refer: 6). If nominated individually, organizers will form a team using \npower of AI.'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    408.4700012207031,
#    285.48199462890625,
#    422.3299865722656),
#   'content': '13.10.10. Will resources be provided?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (108.0199966430664,
#    437.1099853515625,
#    526.1199340820312,
#    466.02996826171875),
#   'content': 'Yes. Participants will receive Laptop loaded with Python, VS Code, access to open \nInternet, relevant tools, and mentoring support.'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    478.92999267578125,
#    528.77197265625,
#    492.78997802734375),
#   'content': '13.10.11. What mindset should I have while building my solution for the AI Hackathon?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (108.0199966430664,
#    507.66998291015625,
#    525.66796875,
#    536.5899658203125),
#   'content': 'You should build your solution with an enterprise application development \nmindset, focusing on scalability, reliability, and maintainability.'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    549.489990234375,
#    359.7820129394531,
#    563.3499755859375),
#   'content': '13.10.12. What tools or platforms will we be using?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (108.0199966430664,
#    578.22998046875,
#    525.7159423828125,
#    607.0299682617188),
#   'content': 'Common tools include Python, Jupyter Notebooks, TensorFlow, PyTorch, \nHugging Face, OpenAI APIs, and GitHub.'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688,
#    620.0800170898438,
#    430.4620056152344,
#    633.9400024414062),
#   'content': '13.10.13. Will there be any mentorship or support during the Lab?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (108.0199966430664,
#    648.8199462890625,
#    525.6559448242188,
#    677.6199951171875),
#   'content': 'Yes. Mentors will be available during scheduled hours to help with technical, \nconceptual, and project-related questions.'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (96.38400268554688, 690.6400146484375, 375.98199462890625, 704.5),
#   'content': '13.10.14. What if I face technical issues during the Lab?'},
#  {'modality': 'text',
#   'page': 20,
#   'bbox': (108.0199966430664,
#    719.3800048828125,
#    525.9578857421875,
#    748.1759643554688),
#   'content': 'A Digital Infrastructure Support (DIS) team will be available to help troubleshoot \ntechnical problems.'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (437.739990234375,
#    780.0660400390625,
#    530.6919555664062,
#    804.5999755859375),
#   'content': 'TCS Confidential | 21'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (96.38400268554688,
#    72.53996276855469,
#    525.787841796875,
#    86.39996337890625),
#   'content': '13.10.15. What frameworks or tools are recommended for building a scalable solution'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (121.58000183105469,
#    91.219970703125,
#    230.8820037841797,
#    103.219970703125),
#   'content': 'in the AI Hackathon?'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (108.0199966430664,
#    118.0999755859375,
#    525.6680297851562,
#    146.89996337890625),
#   'content': 'You should build your solution with an enterprise application development \nmindset, focusing on scalability, reliability, and maintainability.'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (96.38400268554688,
#    159.9199676513672,
#    484.8520202636719,
#    173.77996826171875),
#   'content': '13.10.16. Can I use ChatGPT to craft my entire solution for the AI Hackathon?'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (108.0199966430664,
#    188.65997314453125,
#    525.7279663085938,
#    217.4599609375),
#   'content': 'No, it is recommended to avoid relying entirely on ChatGPT and instead use your \nown development skills to build a scalable and maintainable solution.'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (96.38400268554688,
#    230.47996520996094,
#    494.0920104980469,
#    244.3399658203125),
#   'content': '13.10.17. Can I use existing GitHub repositories to develop my entire solution?'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (108.0199966430664, 259.25, 525.8001098632812, 304.8499755859375),
#   'content': 'No, it is recommended to avoid cloning or directly using entire GitHub repositories. \nInstead, use them as a reference or inspiration to build your own solution, \ndemonstrating your development skills and creativity.'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (96.38400268554688,
#    317.8699951171875,
#    500.6920166015625,
#    331.72998046875),
#   'content': '13.10.18. Can I use external APIs or Model-as-a-Service for my primary solution?'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (108.0199966430664,
#    346.6099853515625,
#    525.6319580078125,
#    392.3299865722656),
#   'content': 'No, to ensure a level playing field, please use the underlying infrastructure and \nmodels provided for the hackathon. This means avoiding external APIs or Model-as-a-\nService for your primary solution that will be evaluated.'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (96.38400268554688,
#    405.2300109863281,
#    513.77197265625,
#    419.0899963378906),
#   'content': '13.10.19. Will I get to experiment on latest AI technologies like MCP, GraphDB etc?'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (108.0199966430664,
#    433.989990234375,
#    525.716064453125,
#    462.78997802734375),
#   'content': 'Organizing committee is exploring all possibilities to bring latest technologies on \nboard for all participant to experiment and explore.'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (96.38400268554688,
#    475.80999755859375,
#    526.1199951171875,
#    489.66998291015625),
#   'content': '13.10.20. Will I have another chance to participate in the Hackathon if I do not make it'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (121.58000183105469,
#    494.5899963378906,
#    260.5220031738281,
#    506.5899963378906),
#   'content': 'through the initial rounds?'},
#  {'modality': 'text',
#   'page': 21,
#   'bbox': (108.0199966430664,
#    521.3499755859375,
#    526.095947265625,
#    550.27001953125),
#   'content': 'There will be a cooling period of one quarter following your last attempt. However, \nplease note that this will be at the discretion of the organizing committee.'}]

# %% [markdown]
# ### Tables from PDF

# %%
import pdfplumber
import pandas as pd

def extract_tables(pdf_path):
    tables = []
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages, start=1):
            page_tables = page.extract_tables()
            for t_index, t in enumerate(page_tables):
                df = pd.DataFrame(t[1:], columns=t[0])  # heuristic: first row headers
                tables.append({
                    "modality": "table",
                    "page": i,
                    "content_csv": df.to_csv(index=False),
                    "content_md": df.to_markdown(index=False),
                    "shape": df.shape
                })
    return tables
tables = extract_tables("./docs/doc.pdf")

# %%
tables
# Out:
# [{'modality': 'table',
#   'page': 3,
#   'content_csv': ',Revision/,,,Document,,"Revision\nDescription","Section\nNo.","Rational for\nChange",,Change type,\n,Version,,,Release/Revision,,,,,,(add/modify,\n,No.,,,Date,,,,,,/delete),\n1.0,,,01-08-2025,,,"First release of\nthe document",NA,NA,NA,,\n,,,,,,,,,,,\n,,,,,,,,,,,\n',
#   'content_md': '|     | Revision/   |    |            | Document         |    | Revision         | Section   | Rational for   |    | Change type   |    |\n|     |             |    |            |                  |    | Description      | No.       | Change         |    |               |    |\n|:----|:------------|:---|:-----------|:-----------------|:---|:-----------------|:----------|:---------------|:---|:--------------|:---|\n|     | Version     |    |            | Release/Revision |    |                  |           |                |    | (add/modify   |    |\n|     | No.         |    |            | Date             |    |                  |           |                |    | /delete)      |    |\n| 1.0 |             |    | 01-08-2025 |                  |    | First release of | NA        | NA             | NA |               |    |\n|     |             |    |            |                  |    | the document     |           |                |    |               |    |',
#   'shape': (5, 12)},
#  {'modality': 'table',
#   'page': 3,
#   'content_csv': 'Revision\nDescription\n',
#   'content_md': '| Revision    |\n|:------------|\n| Description |',
#   'shape': (1, 1)},
#  {'modality': 'table',
#   'page': 3,
#   'content_csv': 'Section\nNo.\n',
#   'content_md': '| Section   |\n|:----------|\n| No.       |',
#   'shape': (1, 1)},
#  {'modality': 'table',
#   'page': 3,
#   'content_csv': 'Rational for\nChange\n',
#   'content_md': '| Rational for   |\n|:---------------|\n| Change         |',
#   'shape': (1, 1)},
#  {'modality': 'table',
#   'page': 9,
#   'content_csv': '#,Topic,Start Time,End Time,Duration\n1,Match Time,2:00 PM,7.00 PM,5:00\n2,Demo & Evaluation,7:00 PM,8:00 PM,1:00\n3,Announce winners,8:00 PM,8:30 PM,0:30\n',
#   'content_md': '|   # | Topic             | Start Time   | End Time   | Duration   |\n|----:|:------------------|:-------------|:-----------|:-----------|\n|   1 | Match Time        | 2:00 PM      | 7.00 PM    | 5:00       |\n|   2 | Demo & Evaluation | 7:00 PM      | 8:00 PM    | 1:00       |\n|   3 | Announce winners  | 8:00 PM      | 8:30 PM    | 0:30       |',
#   'shape': (3, 5)},
#  {'modality': 'table',
#   'page': 17,
#   'content_csv': ',Branch,,,SPOC Emp ID,,,SPOC Name,,,Lab Locations,\nAhmedabad,,,"1. 671041\n2. 172747",,,"1. Mayank Patel\n2. Priti Vyas",,,"Block1, Floor 3, ODC-8",,\nBangalore,,,"1.118270\n2.469133",,,"1. Savitha Rodrigues\n2. Deepak Singhi",,,"1. Anchor - TR1 & TR2, 8th Floor\n2. Pioneer - Saranga TR - First\nFloor\n3. Think campus - TR4, B4\nBuilding",,\nChennai,,,1. 588968,,,1. Narmada G,,,"Siruseri, Signature Tower, 1st\nFloor, D2 Module",,\nHyderabad,,,"1. 112898\n2. 124014",,,"1. Praveen Vadapally\n2. Sirisha Pera",,,"1. Synergy Park, MPH, 3F ODC6\n2. Adibatla S4-1-Z11",,\nPune,,,"1. 1058982\n2. 570096\n3. 1061926",,,"1. Varsha Kini\n2. Jyoti Raut\n3. Esther David",,,"1.SP2 Tower 2 TR1\n2. Commerzone 5th Floor CR\n3. Quadra TR-1",,\nMumbai,,,"1. 170866\n2. 336312",,,1. Yashasree Barve,,,"1. TCS Olympus A, 8 E\n2 . Powai Ken (TBC)",,\n',
#   'content_md': '|           | Branch   |    |            | SPOC Emp ID   |    |                      | SPOC Name   |    |                                  | Lab Locations   |    |\n|:----------|:---------|:---|:-----------|:--------------|:---|:---------------------|:------------|:---|:---------------------------------|:----------------|:---|\n| Ahmedabad |          |    | 1. 671041  |               |    | 1. Mayank Patel      |             |    | Block1, Floor 3, ODC-8           |                 |    |\n|           |          |    | 2. 172747  |               |    | 2. Priti Vyas        |             |    |                                  |                 |    |\n| Bangalore |          |    | 1.118270   |               |    | 1. Savitha Rodrigues |             |    | 1. Anchor - TR1 & TR2, 8th Floor |                 |    |\n|           |          |    | 2.469133   |               |    | 2. Deepak Singhi     |             |    | 2. Pioneer - Saranga TR - First  |                 |    |\n|           |          |    |            |               |    |                      |             |    | Floor                            |                 |    |\n|           |          |    |            |               |    |                      |             |    | 3. Think campus - TR4, B4        |                 |    |\n|           |          |    |            |               |    |                      |             |    | Building                         |                 |    |\n| Chennai   |          |    | 1. 588968  |               |    | 1. Narmada G         |             |    | Siruseri, Signature Tower, 1st   |                 |    |\n|           |          |    |            |               |    |                      |             |    | Floor, D2 Module                 |                 |    |\n| Hyderabad |          |    | 1. 112898  |               |    | 1. Praveen Vadapally |             |    | 1. Synergy Park, MPH, 3F ODC6    |                 |    |\n|           |          |    | 2. 124014  |               |    | 2. Sirisha Pera      |             |    | 2. Adibatla S4-1-Z11             |                 |    |\n| Pune      |          |    | 1. 1058982 |               |    | 1. Varsha Kini       |             |    | 1.SP2 Tower 2 TR1                |                 |    |\n|           |          |    | 2. 570096  |               |    | 2. Jyoti Raut        |             |    | 2. Commerzone 5th Floor CR       |                 |    |\n|           |          |    | 3. 1061926 |               |    | 3. Esther David      |             |    | 3. Quadra TR-1                   |                 |    |\n| Mumbai    |          |    | 1. 170866  |               |    | 1. Yashasree Barve   |             |    | 1. TCS Olympus A, 8 E            |                 |    |\n|           |          |    | 2. 336312  |               |    |                      |             |    | 2 . Powai Ken (TBC)              |                 |    |',
#   'shape': (6, 12)},
#  {'modality': 'table',
#   'page': 18,
#   'content_csv': ',,"2. Lakshmi\nVaidyalingam",\nKolkata,"1. 111764\n2. 1122453\n3. 1006238","1. Sanjukta Ray\n2. Bratati Roy\n3. Abhinandan\nBanerjee",Gitanjali Park ODC- 3-B-3\nNew Delhi,"1. 146663\n2. 109810\n3. 679390","1. Amit Gupta\n2. Anupama Singh\n3. Sugandh\nSarvpriya",\nBhubaneswar,"1. 522770\n2. 346219\n3. 163823","1. Nishipadma\nMishra\n2. Biswaranjan Jena\n3. Bijoy Ketan Panda",Hirakud - 2F-ADC-2B\nIndore,"1. 2312426\n2. 355465","1. Kriyesh Patidar\n2. Shikhar Dadhich","Ground Floor, L1 Block"\nKochi,"1. 142447\n2. 170419\n3. 108149\n4. 142418","1. Arun Narayan\nThekkethil\n2. Prasad Panthayil\n3. Reeja George\n4. Robin John","""Gurukool”, 6th Floor, Vismaya\nBuilding, Infopark"\nTrivandrum,1. 158296,1. Rakesh Unnee,"Block B, 2nd floor ODC 4"\nNagpur,"1. 333913\n2. 869063","1. Devashish Rao\n2. Sarang Bhalerao","EB7, G Floor, ODC C"\nLucknow,"1. 107613\n2. 141183","1. Ambili K\n2. Manish Rajput","7th Floor, TCS Awadh Park"\nVaranasi,"1. 143210\n2. 1529363","1. Ravi Kohli\n2. Dhruv Kumar","TCS Siddha Complex, Floor 2, 3 &\n4 Internet Kiosk Rooms"\n',
#   'content_md': '|             |            | 2. Lakshmi           |                                  |\n|             |            | Vaidyalingam         |                                  |\n|:------------|:-----------|:---------------------|:---------------------------------|\n| Kolkata     | 1. 111764  | 1. Sanjukta Ray      | Gitanjali Park ODC- 3-B-3        |\n|             | 2. 1122453 | 2. Bratati Roy       |                                  |\n|             | 3. 1006238 | 3. Abhinandan        |                                  |\n|             |            | Banerjee             |                                  |\n| New Delhi   | 1. 146663  | 1. Amit Gupta        |                                  |\n|             | 2. 109810  | 2. Anupama Singh     |                                  |\n|             | 3. 679390  | 3. Sugandh           |                                  |\n|             |            | Sarvpriya            |                                  |\n| Bhubaneswar | 1. 522770  | 1. Nishipadma        | Hirakud - 2F-ADC-2B              |\n|             | 2. 346219  | Mishra               |                                  |\n|             | 3. 163823  | 2. Biswaranjan Jena  |                                  |\n|             |            | 3. Bijoy Ketan Panda |                                  |\n| Indore      | 1. 2312426 | 1. Kriyesh Patidar   | Ground Floor, L1 Block           |\n|             | 2. 355465  | 2. Shikhar Dadhich   |                                  |\n| Kochi       | 1. 142447  | 1. Arun Narayan      | "Gurukool”, 6th Floor, Vismaya   |\n|             | 2. 170419  | Thekkethil           | Building, Infopark               |\n|             | 3. 108149  | 2. Prasad Panthayil  |                                  |\n|             | 4. 142418  | 3. Reeja George      |                                  |\n|             |            | 4. Robin John        |                                  |\n| Trivandrum  | 1. 158296  | 1. Rakesh Unnee      | Block B, 2nd floor ODC 4         |\n| Nagpur      | 1. 333913  | 1. Devashish Rao     | EB7, G Floor, ODC C              |\n|             | 2. 869063  | 2. Sarang Bhalerao   |                                  |\n| Lucknow     | 1. 107613  | 1. Ambili K          | 7th Floor, TCS Awadh Park        |\n|             | 2. 141183  | 2. Manish Rajput     |                                  |\n| Varanasi    | 1. 143210  | 1. Ravi Kohli        | TCS Siddha Complex, Floor 2, 3 & |\n|             | 2. 1529363 | 2. Dhruv Kumar       | 4 Internet Kiosk Rooms           |',
#   'shape': (9, 4)},
#  {'modality': 'table',
#   'page': 19,
#   'content_csv': 'S.No.,Course ID,Course Name,Link\n1.,5386,Digital: Python,iEvolve\n2.,5406,Digital: Deep Learning,iEvolve\n3.,5407,Digital: Machine Learning,iEvolve\n4.,5416,Digital: Artificial Intelligence,iEvolve\n5.,6618,Generative AI,iEvolve\n6.,62757,Learning REST APIs,iEvolve\n7.,83068,"Agentic AI Fundamentals:\nArchitectures, Frameworks,\nand Applications_LinkedIn",iEvolve\n8.,83071,"Agentic AI for Developers:\nConcepts and Application for\nEnterprises_LinkedIn",iEvolve\n',
#   'content_md': '|   S.No. |   Course ID | Course Name                      | Link    |\n|--------:|------------:|:---------------------------------|:--------|\n|       1 |        5386 | Digital: Python                  | iEvolve |\n|       2 |        5406 | Digital: Deep Learning           | iEvolve |\n|       3 |        5407 | Digital: Machine Learning        | iEvolve |\n|       4 |        5416 | Digital: Artificial Intelligence | iEvolve |\n|       5 |        6618 | Generative AI                    | iEvolve |\n|       6 |       62757 | Learning REST APIs               | iEvolve |\n|       7 |       83068 | Agentic AI Fundamentals:         | iEvolve |\n|         |             | Architectures, Frameworks,       |         |\n|         |             | and Applications_LinkedIn        |         |\n|       8 |       83071 | Agentic AI for Developers:       | iEvolve |\n|         |             | Concepts and Application for     |         |\n|         |             | Enterprises_LinkedIn             |         |',
#   'shape': (8, 4)}]

# %% [markdown]
# ### Images from PDF

# %%
import fitz
import io
from PIL import Image
import hashlib

def extract_images(pdf_path):
    doc = fitz.open(pdf_path)
    items = []
    for page_index in range(len(doc)):
        page = doc[page_index]
        for img_index, img in enumerate(page.get_images(full=True)):
            xref = img[0]
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]
            pil_img = Image.open(io.BytesIO(image_bytes)).convert("RGB")
            img_hash = hashlib.md5(image_bytes).hexdigest()
            items.append({
                "modality": "image",
                "page": page_index + 1,
                "image_bytes": image_bytes,
                "image_format": base_image.get("ext", "png"),
                "image_hash": img_hash,
                "width": pil_img.width,
                "height": pil_img.height
            })
    doc.close()
    return items
images = extract_images("./docs/doc.pdf")

# %%
for i in range(len(images)):
    Image.open(io.BytesIO(images[i]['image_bytes'])).show()

# %% [markdown]
# ### Image to Text

# %%
for i in range(10):
    img = Image.open(io.BytesIO(images[i]['image_bytes']))
    text = pytesseract.image_to_string(img)
    print(text)
# Out:
# TATA
# tCs CONSULTANCY
# SERVICES TATA
#
#
#
#
#
#
# Participant Journey Map
#
# Hackathon Feedback
#
# + Suomit your *Youwill get mail *Check youraccess *Collaborate with + Present your _—_—« Provide Feedback
# Nomination confirmation tothelocation your Team solution to Jury + Share your
# before Due Date * Orientation ‘Verify yourlogin *Seek Mentor for and Audience Experience
# Alla credentials Guidance sTimebox of 5
# Provisioning Familiarize with Al * Build Scalable, Minutes
# Tools Maintainable
#
# Solution

# %%
import fitz
import pytesseract
from PIL import Image
import io

def ocr_page_images(images):
    ocr_items = []
    for page_num in range(len(images)):
        img = Image.open(io.BytesIO(images[page_num]['image_bytes']))
        text = pytesseract.image_to_string(img)
        ocr_items.append({
            "modality": "ocr_text",
            "page": page_num + 1,
            "content": text
        })
    return ocr_items

image_text = ocr_page_images(images)

# %%
image_text
# Out:
# [{'modality': 'ocr_text',
#   'page': 1,
#   'content': 'TATA\ntCs CONSULTANCY\nSERVICES TATA\n'},
#  {'modality': 'ocr_text', 'page': 2, 'content': ''},
#  {'modality': 'ocr_text', 'page': 3, 'content': ''},
#  {'modality': 'ocr_text', 'page': 4, 'content': ''},
#  {'modality': 'ocr_text', 'page': 5, 'content': ''},
#  {'modality': 'ocr_text', 'page': 6, 'content': ''},
#  {'modality': 'ocr_text',
#   'page': 7,
#   'content': 'Participant Journey Map\n\nHackathon Feedback\n\n+ Suomit your *Youwill get mail *Check youraccess *Collaborate with + Present your _—_—« Provide Feedback\nNomination confirmation tothelocation your Team solution to Jury + Share your\nbefore Due Date * Orientation ‘Verify yourlogin *Seek Mentor for and Audience Experience\nAlla credentials Guidance sTimebox of 5\nProvisioning Familiarize with Al * Build Scalable, Minutes\nTools Maintainable\n\nSolution\n'},
#  {'modality': 'ocr_text', 'page': 8, 'content': ''},
#  {'modality': 'ocr_text', 'page': 9, 'content': ''},
#  {'modality': 'ocr_text', 'page': 10, 'content': ''},
#  {'modality': 'ocr_text', 'page': 11, 'content': ''},
#  {'modality': 'ocr_text', 'page': 12, 'content': ''},
#  {'modality': 'ocr_text', 'page': 13, 'content': ''},
#  {'modality': 'ocr_text', 'page': 14, 'content': ''},
#  {'modality': 'ocr_text',
#   'page': 15,
#   'content': 'Al Lab MaaS Virtual Network\n\nH <> Gateway |\n\nSubnet\n\nWAF &—)\n\nApplication\nGateway\n\n? TCS Al Lab Subscription\nAzure/GCP/AWS “y\nTenant (TCS Al\n\nLAB) | Active Directory\n\n> LUM Subnet\n\nody —> A GS\n><> (0,9)\npays— &\n\n@-\n\nPrivate DNS.\n\nae\nGEN AI LAB\n\n(PAN India\n\nLocations)\n\nLangfuse Container || LiteLLM Gateway\n® App Container App\n\na\nContainer Registry Log Analytics\n\nPostgreSQL\nDatabase\n\n'},
#  {'modality': 'ocr_text', 'page': 16, 'content': ''},
#  {'modality': 'ocr_text',
#   'page': 17,
#   'content': 'B}powersne A ty Ow -~ 3 x\n\nLn 113,Col9(I9selected) Spaces:4 UTF-8 CRLF {} Python 3.119 O\n\n7) A ee\n'},
#  {'modality': 'ocr_text', 'page': 18, 'content': ''},
#  {'modality': 'ocr_text', 'page': 19, 'content': ''},
#  {'modality': 'ocr_text', 'page': 20, 'content': ''},
#  {'modality': 'ocr_text', 'page': 21, 'content': ''},
#  {'modality': 'ocr_text', 'page': 22, 'content': ''},
#  {'modality': 'ocr_text', 'page': 23, 'content': ''},
#  {'modality': 'ocr_text', 'page': 24, 'content': ''}]

# %%
{
  "id": "string",
  "content": "string | markdown | csv (for tables)",
  "modality": "text|table|image|ocr_text",
  "embedding": [float, ...],
  "metadata": {
    "source_pdf": "file.pdf",
    "page": 12,
    "bbox": [x0, y0, x1, y1],
    "table_format": "markdown|csv",
    "image_hash": "md5hex",
    "width": 1200,
    "height": 800,
    "chunk_id": "page12_chunk3",
    "created_at": "2025-11-28T10:37:05+05:30"
  }
}

# %%
from chromadb import Client
from chromadb.config import Settings

client = Client(Settings(anonymized_telemetry=False))
collection = client.get_or_create_collection(name="pdf_rag")

def upsert_items(items, embeddings):
    ids = [it.get("id") for it in items]
    metadatas = [it.get("metadata") for it in items]
    documents = [it.get("content") for it in items]
    collection.upsert(
        ids=ids,
        metadatas=metadatas,
        documents=documents,
        embeddings=embeddings
    )

# %%
def retrieve(query, k=8):
    q_vec = embed_texts([query])[0]
    results = collection.query(
        query_embeddings=[q_vec],
        n_results=k
    )
    return results  # documents + metadata

def build_context(results):
    lines = []
    for doc, meta in zip(results["documents"][0], results["metadatas"][0]):
        lines.append(f"### Source: {meta['source_pdf']} p.{meta['page']} ({meta['modality']})\n")
        if meta.get("table_format") == "markdown":
            lines.append(doc[:4000])  # cap length
        else:
            lines.append(doc[:1200])
        lines.append("\n")
    return "\n".join(lines)

# %%
def process_pdf_to_vectors(pdf_path):
    text_items = extract_text_blocks(pdf_path)
    table_items = extract_tables(pdf_path)
    image_items = extract_images(pdf_path)
    ocr_items = ocr_page_images(pdf_path)  # optional

    # Chunk text
    chunked = []
    for it in text_items:
        chunks = chunk_text(it["content"])
        for idx, ch in enumerate(chunks):
            chunked.append({
                "id": f"{pdf_path}-p{it['page']}-t{idx}",
                "content": ch,
                "modality": "text",
                "metadata": {
                    "source_pdf": pdf_path,
                    "page": it["page"],
                    "bbox": it["bbox"],
                    "chunk_id": f"p{it['page']}_text_{idx}"
                }
            })

    # Prepare tables
    table_docs = []
    for idx, t in enumerate(table_items):
        table_docs.append({
            "id": f"{pdf_path}-table-{idx}",
            "content": t["content_md"],           # prefer markdown for LLMs
            "modality": "table",
            "metadata": {
                "source_pdf": pdf_path,
                "page": t["page"],
                "table_format": "markdown",
                "shape": t["shape"]
            }
        })

    # Prepare images (with optional OCR text as caption)
    image_docs = []
    for idx, img in enumerate(image_items):
        image_docs.append({
            "id": f"{pdf_path}-image-{idx}",
            "content": f"[IMAGE] {img['image_hash']}",  # store a placeholder; embed separately
            "modality": "image",
            "metadata": {
                "source_pdf": pdf_path,
                "page": img["page"],
                "image_hash": img["image_hash"],
                "width": img["width"],
                "height": img["height"]
            },
            "binary": img["image_bytes"]  # store externally or as a blob
        })

    # Embed and upsert text + tables
    text_vectors = embed_texts([d["content"] for d in chunked + table_docs])
    upsert_items(chunked + table_docs, text_vectors)

    # Embed and upsert images (image vectors)
    image_vectors = embed_images([d["binary"] for d in image_docs])
    upsert_items(
        [{**{"content": ""}, **{k: v for k, v in d.items() if k != "binary"}} for d in image_docs],
        image_vectors
    )

    # Optionally: also embed image captions/OCR and upsert as text modality for hybrid retrieval

# %% [markdown]
# ### y-threshold + Repeated Content

# %%
import fitz
from collections import Counter
import re

def detect_repeated_strings(blocks_per_page, min_pages_ratio=0.6):
    # Count normalized strings across pages
    # blocks_per_page: list of pages, each page has list of {"text": str}
    norm = lambda s: re.sub(r"\s+", " ", s.strip()).lower()
    counter = Counter()
    for page_blocks in blocks_per_page:
        seen = set()
        for b in page_blocks:
            t = norm(b["text"])
            if t and len(t) <= 80:  # short strings typical of headers/footers
                seen.add(t)
        counter.update(seen)
    min_count = int(len(blocks_per_page) * min_pages_ratio)
    return {s for s, c in counter.items() if c >= min_count}

def extract_body_text_without_header_footer(pdf_path, top_ratio=0.1, bottom_ratio=0.1):
    doc = fitz.open(pdf_path)
    HFs = []  # collect blocks for repetition detection
    pages_blocks = []

    # First pass: gather blocks per page
    for p in range(len(doc)):
        page = doc[p]
        height = page.rect.height
        blocks = page.get_text("blocks")  # (x0,y0,x1,y1,text, block_no, ...)
        page_items = []
        for x0, y0, x1, y1, text, *_ in blocks:
            page_items.append({"bbox": (x0, y0, x1, y1), "text": text})
        pages_blocks.append(page_items)

    # Detect repeated short strings likely to be headers/footers
    repeated = detect_repeated_strings(pages_blocks, min_pages_ratio=0.6)

    # Second pass: exclude by y-threshold + repeated strings
    body_pages = []
    for p, page_items in enumerate(pages_blocks, start=1):
        page_height = doc[p-1].rect.height
        top_cut = page_height * top_ratio
        bottom_cut = page_height * (1 - bottom_ratio)

        body_text = []
        for item in page_items:
            x0, y0, x1, y1 = item["bbox"]
            text = item["text"].strip()
            if not text:
                continue

            # Skip if located in header/footer bands
            if y1 <= top_cut or y0 >= bottom_cut:
                continue

            # Skip if matches repeated strings
            norm_text = re.sub(r"\s+", " ", text.lower())
            if norm_text in repeated:
                continue

            # Skip typical page number-only blocks at edges
            if (y0 <= top_cut or y1 >= bottom_cut) and re.fullmatch(r"(page\s*\d+(\s*of\s*\d+)?)|\d+", text.lower()):
                continue

            body_text.append(text)

        body_pages.append({"page": p, "text": "\n".join(body_text)})

    doc.close()
    return body_pages

# %% [markdown]
# ### Removing Headers/Footers from Tables

# %%
import pdfplumber
import pandas as pd

def extract_tables_clean(pdf_path, top_ratio=0.1, bottom_ratio=0.12):
    results = []
    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages, start=1):
            H = page.height
            top_cut, bottom_cut = H*top_ratio, H*(1-bottom_ratio)
            tables = page.find_tables()
            for t in tables:
                # Filter table rows by cell y positions
                rows = []
                for row in t.rows:
                    # Compute row bbox from cell boxes
                    y0 = min(cell.y0 for cell in row.cells if cell is not None)
                    y1 = max(cell.y1 for cell in row.cells if cell is not None)
                    # Skip if in header/footer band
                    if y1 <= top_cut or y0 >= bottom_cut:
                        continue
                    rows.append([cell.get_text().strip() if cell else "" for cell in row.cells])
                if not rows:
                    continue
                # Heuristic: first row headers
                df = pd.DataFrame(rows[1:], columns=rows[0])
                results.append({"page": i, "df": df})
    return results

# %% [markdown]
# ### Deduplication: Text, Tables, Images

# %%
import hashlib, re

def normalize_text(s):
    s = re.sub(r"\s+", " ", s.strip().lower())
    s = re.sub(r"[^\w\s]", "", s)  # optional: strip punctuation
    return s

def text_hash(s):
    return hashlib.sha256(normalize_text(s).encode("utf-8")).hexdigest()

def dedup_text_chunks(chunks):
    seen = set()
    unique = []
    for ch in chunks:
        h = text_hash(ch["content"])
        if h in seen:
            continue
        seen.add(h)
        ch["content_hash"] = h
        unique.append(ch)
    return unique

# %%
import pandas as pd
import hashlib

def table_hash(df: pd.DataFrame):
    # Normalize: strip whitespace in cells
    df2 = df.copy()
    df2 = df2.applymap(lambda x: str(x).strip())
    csv = df2.to_csv(index=False)
    return hashlib.md5(csv.encode("utf-8")).hexdigest()

def dedup_tables(table_docs):
    seen = set()
    unique = []
    for t in table_docs:
        df = t["df"]  # assume you kept the dataframe
        h = table_hash(df)
        if h in seen:
            continue
        seen.add(h)
        t["table_hash"] = h
        unique.append(t)
    return unique

# %%
from PIL import Image
import imagehash
import io

def image_phash(image_bytes):
    img = Image.open(io.BytesIO(image_bytes)).convert("RGB")
    return str(imagehash.phash(img))

def dedup_images(image_items, max_hamming_distance=4):
    # Keep first image for each pHash bucket; small distance considered duplicate
    kept = []
    phashes = []
    for it in image_items:
        ph = image_phash(it["image_bytes"])
        is_dup = False
        for existing in phashes:
            # Hamming distance between hashes
            if imagehash.hex_to_hash(ph) - imagehash.hex_to_hash(existing) <= max_hamming_distance:
                is_dup = True
                break
        if not is_dup:
            phashes.append(ph)
            it["phash"] = ph
            kept.append(it)
    return kept
